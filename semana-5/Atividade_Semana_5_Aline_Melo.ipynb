# %% [markdown]
# # Atividade - Semana 05 - Obtendo dados
#
# Esta é atividade semanal sugerida. Você deverá preenchê-la e enviá-la dentro do prazo (até o fechamento da semana corrente).

# %% [markdown]
# ###Questão 1
#
# Importe a planilha `dados_credito.csv` na pasta virtual `content`.

# %%
# Questao 1
import pandas as pd

dados = pd.read_csv("/content/dados_credito.csv")
dados
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-676e3a9c5ed3> in <cell line: 4>()
#       2 import pandas as pd
#       3
# ----> 4 dados = pd.read_csv("/content/dados_credito.csv")
#       5 dados
#       6
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/dados_credito.csv'

# %% [markdown]
# ###Questão 2
#
# Instale o pacote `ibge` utilizando `pip`.
#
# (use `!` antes do `pip`)

# %%
# Questao 2

# !pip install ibge
# Out:
# Collecting ibge
#   Downloading ibge-0.0.5-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ibge) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ibge) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ibge) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ibge) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ibge) (2024.8.30)
# Downloading ibge-0.0.5-py3-none-any.whl (6.4 kB)
# Installing collected packages: ibge
# Successfully installed ibge-0.0.5

# %% [markdown]
# ###Questão 3
#
# Similar ao feito no *script da semana 05*, busque informações sobre Estados diretamente do IBGE utilizando a função `Estados()`.
#
# (Não esqueça de importar o pacote corretamente)
#
# (Troque o comando `Municipios()` por `Estados()` utilizando o script da semana 05)

# %%
# Questao 3
from ibge.localidades import *

est = Estados()
df_est = pd.json_normalize(est.json())
df_est
# Out:
#     id sigla                 nome  regiao.id regiao.sigla   regiao.nome
# 0   11    RO             Rondônia          1            N         Norte
# 1   12    AC                 Acre          1            N         Norte
# 2   13    AM             Amazonas          1            N         Norte
# 3   14    RR              Roraima          1            N         Norte
# 4   15    PA                 Pará          1            N         Norte
# 5   16    AP                Amapá          1            N         Norte
# 6   17    TO            Tocantins          1            N         Norte
# 7   21    MA             Maranhão          2           NE      Nordeste
# 8   22    PI                Piauí          2           NE      Nordeste
# 9   23    CE                Ceará          2           NE      Nordeste
# 10  24    RN  Rio Grande do Norte          2           NE      Nordeste
# 11  25    PB              Paraíba          2           NE      Nordeste
# 12  26    PE           Pernambuco          2           NE      Nordeste
# 13  27    AL              Alagoas          2           NE      Nordeste
# 14  28    SE              Sergipe          2           NE      Nordeste
# 15  29    BA                Bahia          2           NE      Nordeste
# 16  31    MG         Minas Gerais          3           SE       Sudeste
# 17  32    ES       Espírito Santo          3           SE       Sudeste
# 18  33    RJ       Rio de Janeiro          3           SE       Sudeste
# 19  35    SP            São Paulo          3           SE       Sudeste
# 20  41    PR               Paraná          4            S           Sul
# 21  42    SC       Santa Catarina          4            S           Sul
# 22  43    RS    Rio Grande do Sul          4            S           Sul
# 23  50    MS   Mato Grosso do Sul          5           CO  Centro-Oeste
# 24  51    MT          Mato Grosso          5           CO  Centro-Oeste
# 25  52    GO                Goiás          5           CO  Centro-Oeste
# 26  53    DF     Distrito Federal          5           CO  Centro-Oeste

# %% [markdown]
# ###Questão 4
#
# Instale o pacote `sgs` utilizando `pip`.
#
# (use `!` antes do `pip`)

# %%
# Questao 4

# !pip install sgs
# Out:
# Requirement already satisfied: sgs in /usr/local/lib/python3.10/dist-packages (2.1.1)
# Requirement already satisfied: beautifulsoup4>=4.7.1 in /usr/local/lib/python3.10/dist-packages (from sgs) (4.12.3)
# Requirement already satisfied: html5lib>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from sgs) (1.1)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from sgs) (2.2.2)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from sgs) (1.3.4)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.10/dist-packages (from sgs) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.7.1->sgs) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.0.1->sgs) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.0.1->sgs) (0.5.1)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->sgs) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->sgs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->sgs) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->sgs) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->sgs) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->sgs) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->sgs) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.22.0->sgs) (2024.8.30)

# %% [markdown]
# ###Questão 5
#
# Similar ao feito no *script da semana 05*, busque informações no sistema `sgs` sobre o _salário mínimo histórico_ **de 01/01/1990 a 01/03/2023** (código da série: 1619)
#
# (Não esqueça de importar o pacote corretamente)

# %%
# Questao 5
# Importando o pacote necessário
import sgs

# Buscando informações sobre o salário mínimo histórico
df_salario = sgs.dataframe(1619, start='01/01/1990', end='01/03/2023')

# Exibindo os dados
print(df_salario)
# Out:
#                1619
# 1990-02-01  2004.37
# 1990-03-01  3674.06
# 1990-04-01  3674.06
# 1990-05-01  3674.06
# 1990-06-01  3857.76
# ...             ...
# 2022-11-01  1212.00
# 2022-12-01  1212.00
# 2023-01-01  1302.00
# 2023-02-01  1302.00
# 2023-03-01  1302.00
#
# [398 rows x 1 columns]

# %% [markdown]
# ###Questão 6
#
# Instale o pacote `ipeadatapy` utilizando `pip`.
#
# (use `!` antes do `pip`)

# %%
# Questao 6
# !pip install ipeadatapy
# Out:
# Requirement already satisfied: ipeadatapy in /usr/local/lib/python3.10/dist-packages (0.1.9)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ipeadatapy) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ipeadatapy) (2.32.3)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas->ipeadatapy) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ipeadatapy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ipeadatapy) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->ipeadatapy) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ipeadatapy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ipeadatapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ipeadatapy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ipeadatapy) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ipeadatapy) (1.16.0)

# %% [markdown]
# ###Questão 7
#
# Similar ao feito no *script da semana 05*, busque informações na base `ipeadata` sobre a _produção de café no Brasil em toneladas_ (código da série: `LSPA_QCAFE`)
#
# (Não esqueça de importar o pacote corretamente)

# %%
# Questao 7
import ipeadatapy

# o codigo da serie de salario minimo na base
# e 'GAC12_SALMINRE12'
df_cafe = ipeadatapy.timeseries('LSPA_QCAFE')
df_cafe
# Out:
#                   CODE                   RAW DATE  DAY  MONTH  YEAR  \
# DATE
# 1900-01-01  LSPA_QCAFE  1900-01-01T00:00:00-02:00    1      1  1900
# 1901-01-01  LSPA_QCAFE  1901-01-01T00:00:00-02:00    1      1  1901
# 1902-01-01  LSPA_QCAFE  1902-01-01T00:00:00-02:00    1      1  1902
# 1903-01-01  LSPA_QCAFE  1903-01-01T00:00:00-02:00    1      1  1903
# 1904-01-01  LSPA_QCAFE  1904-01-01T00:00:00-02:00    1      1  1904
# ...                ...                        ...  ...    ...   ...
# 2018-01-01  LSPA_QCAFE  2018-01-01T00:00:00-02:00    1      1  2018
# 2019-01-01  LSPA_QCAFE  2019-01-01T00:00:00-02:00    1      1  2019
# 2020-01-01  LSPA_QCAFE  2020-01-01T00:00:00-03:00    1      1  2020
# 2021-01-01  LSPA_QCAFE  2021-01-01T00:00:00-03:00    1      1  2021
# 2022-01-01  LSPA_QCAFE  2022-01-01T00:00:00-03:00    1      1  2022
#
#             VALUE (Tonelada)
# DATE
# 1900-01-01          564000.0
# 1901-01-01          678000.0
# 1902-01-01          966000.0
# 1903-01-01          774000.0
# 1904-01-01          666000.0
# ...                      ...
# 2018-01-01         3551865.0
# 2019-01-01         3011745.0
# 2020-01-01         3705719.0
# 2021-01-01         2985581.0
# 2022-01-01         3172562.0
#
# [123 rows x 6 columns]
